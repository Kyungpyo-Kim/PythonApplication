# %% [markdown]
# # install pybithumb

# %%
# !python3 -m pip install -U pybithumb
# Out:
# Collecting pybithumb
#   Downloading pybithumb-1.0.21-py3-none-any.whl (9.9 kB)
# Requirement already satisfied, skipping upgrade: html5lib in /usr/lib/python3/dist-packages (from pybithumb) (1.0.1)
# Collecting websockets
#   Downloading websockets-8.1-cp38-cp38-manylinux2010_x86_64.whl (78 kB)
#      |████████████████████████████████| 78 kB 616 kB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: pandas in /usr/lib/python3/dist-packages (from pybithumb) (0.25.3)
# Requirement already satisfied, skipping upgrade: requests in /usr/lib/python3/dist-packages (from pybithumb) (2.22.0)
# Collecting datetime
#   Downloading DateTime-4.3-py2.py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 4.1 MB/s eta 0:00:01
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
# Requirement already satisfied, skipping upgrade: pytz in /usr/lib/python3/dist-packages (from datetime->pybithumb) (2019.3)
# Requirement already satisfied, skipping upgrade: zope.interface in /usr/lib/python3/dist-packages (from datetime->pybithumb) (4.7.1)
# Requirement already satisfied, skipping upgrade: beautifulsoup4 in /usr/lib/python3/dist-packages (from bs4->pybithumb) (4.8.2)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1272 sha256=2a4cbaaa4444dc27bf1ae4f4deadb1f870889fba92b7861ea5022e3816bbf0cf
#   Stored in directory: /home/kyungpyo/.cache/pip/wheels/75/78/21/68b124549c9bdc94f822c02fb9aa3578a669843f9767776bca
# Successfully built bs4
# Installing collected packages: websockets, datetime, bs4, pybithumb
# Successfully installed bs4-0.0.1 datetime-4.3 pybithumb-1.0.21 websockets-8.1

# %%
import pybithumb

## ticker
tickers = pybithumb.get_tickers()
print(tickers)
print(len(tickers))

## price
price = pybithumb.get_current_price("BTC")
print(price)

## detail
detail = pybithumb.get_market_detail("BTC")
print(detail)
desc = ["시가", "고가", "저가", "종가", "거래량"] # description
[print("00시 기준 {}: {}".format(desc[i], value)) 
    for i, value in enumerate(detail)
]

## oderbook
orderbook = pybithumb.get_orderbook("BTC")
print(orderbook)
print(orderbook['payment_currency'])
print(orderbook['order_currency'])

import datetime
ms = int(orderbook["timestamp"])
dt = datetime.datetime.fromtimestamp(ms/1000)
print(dt)

bids = orderbook['bids']
for bid in bids:
    print("매수호가: {}, 매수잔량: {}".format(bid['price'], bid['quantity'])) 

asks = orderbook['asks']
for ask in asks:
    print("매도호가: {}, 매도잔량: {}".format(ask['price'], ask['quantity']))
    
all = pybithumb.get_current_price("ALL")
for ticker, data in all.items():
    print(ticker, data['closing_price'])
# Out:
# ['BTC', 'ETH', 'LTC', 'ETC', 'XRP', 'BCH', 'QTUM', 'BTG', 'EOS', 'ICX', 'TRX', 'ELF', 'OMG', 'KNC', 'GLM', 'ZIL', 'WAXP', 'POWR', 'LRC', 'STEEM', 'STRAX', 'AE', 'ZRX', 'REP', 'XEM', 'SNT', 'ADA', 'CTXC', 'BAT', 'WTC', 'THETA', 'LOOM', 'WAVES', 'TRUE', 'LINK', 'RNT', 'ENJ', 'VET', 'MTL', 'IOST', 'TMTG', 'QKC', 'HDAC', 'WET', 'AMO', 'BSV', 'DAC', 'ORBS', 'TFUEL', 'VALOR', 'CON', 'ANKR', 'MIX', 'LAMB', 'CRO', 'FX', 'CHR', 'MBL', 'MXC', 'DVP', 'FCT', 'FNB', 'TRV', 'PCM', 'DAD', 'AOA', 'XSR', 'WOM', 'SOC', 'EM', 'QBZ', 'BOA', 'FLETA', 'SXP', 'COS', 'APIX', 'EL', 'BASIC', 'HIVE', 'XPR', 'FIT', 'EGG', 'BORA', 'ARPA', 'APM', 'AERGO', 'ANW', 'CENNZ', 'EVZ', 'MCI', 'SRM', 'QTCON', 'UNI', 'YFI', 'UMA', 'AAVE', 'COMP', 'SAND', 'CVT', 'GOM2', 'RINGX', 'BEL', 'DVC', 'OBSR', 'ORC', 'POLA', 'AWO', 'ADP', 'DVI', 'MIR', 'MVC', 'WOZX', 'ANV', 'GRT', 'MM', 'BIOT', 'XNO', 'SNX', 'RAI', 'OXT', 'LINA', 'MKR', 'SUSHI', 'PUNDIX', 'LF', 'BCD', 'XLM', 'GXC', 'BTT', 'VSYS', 'IPX', 'WICC', 'ONT', 'LUNA', 'AION', 'META', 'ONG', 'ALGO', 'JST', 'XTZ', 'MLK', 'WEMIX', 'DOT', 'SUN', 'ATOM', 'SSX', 'BCHA', 'TEMCO', 'BURGER']
# 149
# 77754000.0
# (75443000.0, 79154000.0, 75000000.0, 77754000.0, 3324.30649401)
# 00시 기준 시가: 75443000.0
# 00시 기준 고가: 79154000.0
# 00시 기준 저가: 75000000.0
# 00시 기준 종가: 77754000.0
# 00시 기준 거래량: 3324.30649401
# {'timestamp': '1618057267425', 'payment_currency': 'KRW', 'order_currency': 'BTC', 'bids': [{'price': 77754000.0, 'quantity': 1.0}, {'price': 77751000.0, 'quantity': 0.1297}, {'price': 77750000.0, 'quantity': 0.7401}, {'price': 77742000.0, 'quantity': 0.5073}, {'price': 77741000.0, 'quantity': 0.002}], 'asks': [{'price': 77775000.0, 'quantity': 0.02670715}, {'price': 77782000.0, 'quantity': 0.008}, {'price': 77797000.0, 'quantity': 0.2478}, {'price': 77798000.0, 'quantity': 0.1126}, {'price': 77799000.0, 'quantity': 0.0019}]}
# KRW
# BTC
# 2021-04-10 21:21:07.425000
# 매수호가: 77754000.0, 매수잔량: 1.0
# 매수호가: 77751000.0, 매수잔량: 0.1297
# 매수호가: 77750000.0, 매수잔량: 0.7401
# 매수호가: 77742000.0, 매수잔량: 0.5073
# 매수호가: 77741000.0, 매수잔량: 0.002
# 매도호가: 77775000.0, 매도잔량: 0.02670715
# 매도호가: 77782000.0, 매도잔량: 0.008
# 매도호가: 77797000.0, 매도잔량: 0.2478
# 매도호가: 77798000.0, 매도잔량: 0.1126
# 매도호가: 77799000.0, 매도잔량: 0.0019
# BTC 77754000
# ETH 2780000
# LTC 296900
# ETC 24870
# XRP 1494
# BCH 838500
# QTUM 19690
# BTG 135200
# EOS 8230
# ICX 3440
# TRX 155.4
# ELF 765
# OMG 13170
# KNC 4565
# GLM 773
# ZIL 274.5
# WAXP 332.8
# POWR 781.8
# LRC 731
# STEEM 1696
# STRAX 3247
# AE 665
# ZRX 2938
# REP 68150
# XEM 526
# SNT 230.5
# ADA 1573
# CTXC 455.6
# BAT 1873
# WTC 2786
# THETA 15700
# LOOM 281.5
# WAVES 21980
# TRUE 470
# LINK 41570
# RNT 19.36
# ENJ 4501
# VET 180.8
# MTL 6495
# IOST 69.96
# TMTG 11.72
# QKC 52.23
# HDAC 125
# WET 5.918
# AMO 12.38
# BSV 343100
# DAC 11.03
# ORBS 236.7
# TFUEL 477.2
# VALOR 1382
# CON 11.67
# ANKR 201.9
# MIX 16.67
# LAMB 153.9
# CRO 281.1
# FX 556
# CHR 455
# MBL 31.34
# MXC 63.18
# DVP 84.1
# FCT 321.5
# FNB 13.15
# TRV 47.77
# PCM 36.8
# DAD 463.9
# AOA 9.793
# XSR 4.521
# WOM 335.7
# SOC 18.91
# EM 14.07
# QBZ 14.32
# BOA 501
# FLETA 33.8
# SXP 6975
# COS 51.66
# APIX 152
# EL 40.88
# BASIC 12.97
# HIVE 910.5
# XPR 23.34
# FIT 9.303
# EGG 15.46
# BORA 387.4
# ARPA 180.6
# APM 56.07
# AERGO 622.1
# ANW 207.6
# CENNZ 133.6
# EVZ 159.1
# MCI 45
# SRM 9170
# QTCON 135
# UNI 38810
# YFI 57966000
# UMA 36100
# AAVE 479000
# COMP 578500
# SAND 892.2
# CVT 409
# GOM2 18.01
# RINGX 242
# BEL 7005
# DVC 489.9
# OBSR 44.64
# ORC 3516
# POLA 414.8
# AWO 27.48
# ADP 112.1
# DVI 937
# MIR 16140
# MVC 456.2
# WOZX 2210
# ANV 4389
# GRT 2322
# MM 2430
# BIOT 84.42
# XNO 492.8
# SNX 25380
# RAI 2860
# OXT 1058
# LINA 191.3
# MKR 2960000
# SUSHI 19280
# PUNDIX 6705
# LF 11420
# BCD 3903
# XLM 660
# GXC 1494
# BTT 11.2
# VSYS 65.29
# IPX 88.26
# WICC 672.3
# ONT 2592
# LUNA 20220
# AION 661.9
# META 321
# ONG 1649
# ALGO 1842
# JST 185.7
# XTZ 8425
# MLK 3304
# WEMIX 842.7
# DOT 53850
# SUN 55250
# ATOM 28290
# SSX 222.9
# BCHA 52550
# TEMCO 21.15
# BURGER 7605

# %% [markdown]
# |Key | Description |
# | --- | --- |
# |opening_price	|최근 24시간 내 시작 거래금액|
# |closing_price	|최근 24시간 내 마지막 거래금액|
# |min_price 최근	|24시 간 내 최저 거래금액|
# |max_price 최근	|24시 간 내 최고 거래금액|
# |average_price	|최근 24시간 내 평균 거래금액|
# |units_traded	|최근 24시간 내 Currency 거래량|
# |volume_1day	|최근 1일간 Currency 거래량|
# |volume_7day	|최근 7일간 Currency 거래량|
# |buy_price	|거래 대기건 최고 구매가|
# |sell_price	|거래 대기건 최소 판매가|
# |24H_fluctate	|24시간 변동금액|
# |24H_fluctate_rate	|24시간 변동률|

# %%
import pybithumb

btc = pybithumb.get_ohlcv("BTC")

# moving average
close = btc['close']
ma5 = close.rolling(5).mean()
last_ma5 = ma5[-2]
price = pybithumb.get_current_price("BTC")

if price > last_ma5:
    print("상승장")
else:
    print("하락장")

print(ma5)

def detectBullMarket(ticker, window=5):
    df = pybithumb.get_ohlcv(ticker)
    ma = df['close'].rolling(window=window).mean()
    cur_price = pybithumb.get_current_price(ticker)
    last_ma = ma[-2]
    if price > last_ma:
        return True
    else:
        return False

tickers = pybithumb.get_tickers()
for ticker in tickers:
    is_bull = detectBullMarket(ticker, 5)
    print("{}: {}".format(ticker, "상승장" if is_bull else "하락장"))
# Out:
# 상승장
# time
# 2013-12-27 00:00:00           NaN
# 2013-12-28 00:00:00           NaN
# 2013-12-29 00:00:00           NaN
# 2013-12-30 00:00:00           NaN
# 2013-12-31 00:00:00      756000.0
#                           ...
# 2021-04-06 00:00:00    75217800.0
# 2021-04-07 00:00:00    75027600.0
# 2021-04-08 00:00:00    74837600.0
# 2021-04-09 00:00:00    75287000.0
# 2021-04-10 21:00:00    75539800.0
# Name: close, Length: 2572, dtype: float64
